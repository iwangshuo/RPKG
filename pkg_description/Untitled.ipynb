# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

# doc = nlp('European authorities fined Google a record $5.1 billion on Wednesday for abusing its power in the mobile phone market and ordered the company to alter its practices')
# print([(X.text, X.label_) for X in doc.ents])

from bs4 import BeautifulSoup
import requests
import re
def url_to_string(url):
    res= requests.get(url)
    html= res.text
    soup= BeautifulSoup(html,'html5lib')
    for script in soup(["script","style",'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))
ny_bb= url_to_string('https://www.bbc.com/news/world-us-canada-45173015')
print(ny_bb)
article = nlp(ny_bb)
# print(len(article.ents))
# labels = [x.label_ for x in article.ents]
# print(Counter(labels))
# Out:
# FBI agent Peter Strzok 'fired over anti-Trump texts' - BBC NewsBBC HomepageSkip to contentAccessibility HelpYour accountHomeNewsSportReelWorklifeTravelFutureMore menuMore menuSearch BBCHomeNewsSportReelWorklifeTravelFutureCultureMusicTVWeatherSoundsClose menuBBC NewsMenuHomeWar in UkraineCoronavirusClimateVideoWorldAsiaUKBusinessTechMoreScienceStoriesEntertainment & ArtsHealthWorld News TVIn PicturesReality CheckNewsbeatLong ReadsWorldAfricaAustraliaEuropeLatin AmericaMiddle EastUS & CanadaFBI agent Peter Strzok 'fired over anti-Trump texts'Published13 August 2018Shareclose panelShare pageCopy linkAbout sharingThis video can not be playedTo play this video you need to enable JavaScript in your browser.Media caption, FBI's Peter Strzok: Anti-Trump bias claims 'deeply destructive'A veteran FBI agent who exchanged anti-Trump text messages with a colleague during the election has been fired from the FBI, his lawyer has said.Peter Strzok has been accused by Republicans of being biased aga
# ...

# %%
sentences = [x for x in article.sents]
print(sentences[20])
displacy.render(nlp(str(sentences [20])), jupyter= True, style='ent')
# Out:
# The BBC is not responsible for the content of external sites.
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BBC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is not responsible for the content of external sites.</div></span>

# %%
displacy.render(nlp(str(sentences[20])),style='dep',jupyter= True,options= {'distance':120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="255da344293e40f6941b11fddaa4960b-0" class="displacy" width="1370" height="257.0" direction="ltr" style="max-width: none; height: 257.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">BBC</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
# ...

# %%
displacy.render(article, jupyter= True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FBI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  agent
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter Strzok '
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# fired over anti-Trump texts' -
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BBC
# ...

# %% [markdown]
# # spacy do NER test

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

# doc = nlp('European authorities fined Google a record $5.1 billion on Wednesday for abusing its power in the mobile phone market and ordered the company to alter its practices')
# print([(X.text, X.label_) for X in doc.ents])

from bs4 import BeautifulSoup
import requests
import re
def url_to_string(url):
    res= requests.get(url)
    html= res.text
    soup= BeautifulSoup(html,'html5lib')
    for script in soup(["script","style",'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

# ny_bb= url_to_string('https://www.bbc.com/news/world-us-canada-45173015')
# print(ny_bb)
# article = nlp(ny_bb)

# print(len(article.ents))
# labels = [x.label_ for x in article.ents]
# print(Counter(labels))

# sentences = [x for x in article.sents]
# print(sentences[20])
# displacy.render(nlp(str(sentences [20])), jupyter= True, style='ent')

# %%
from nltk import Tree
from stanfordcorenlp import StanfordCoreNLP

# stf_nlp = StanfordCoreNLP(r'/Users/wshuo/Desktop/data4KG/stanford-corenlp-4.5.3')
stf_nlp = StanfordCoreNLP('http://localhost', port=9999)

sentence = 'The turtlebot3_navigation provides roslaunch scripts for starting the navigation'
# sentence = "The rplidar ros package, support rplidar A2/A1 and A3/S1"

sentence2 = "sound_play provides a ROS node  that translates commands on a ROS topic！"
sentence3 = "PyTables is built on top of the HDF5 library, using the Python language and the NumPy package"
sentence4 = "click Start a new Android Studio Project"
# sentence5 = """
# (declare-fun y () Int)
# (declare-fun v () Bool)
# (assert (\+ v (not (/ y (- 1)))))
# (assert (ite v false ('+' y (- 1))))
# (check-sat)
# """
sentence6 = "I do like eating fish"
sentence7 = "RealSense Camera description package for Intel 3D D400 cameras"
sentence8 = "sound_play provides a ROS node that translates commands on a ROS topic ("
sentence9 = "click Start a new Android Studio Project"
sentence10 = "Common code for working with audio in ROS   "
# print('Tokenize:', nlp.word_tokenize(sentence))
# print('Tokenize:', nlp.word_tokenize(sentence5))
# print('Part of Speech:', nlp.pos_tag(sentence))
# print('Part of Speech:', nlp.pos_tag(sentence2))
# print('Part of Speech:', nlp.pos_tag(sentence3))
# print('Part of Speech:', nlp.pos_tag(sentence))
# print('Named Entities:', nlp.ner(sentence))
# print('Constituency Parsing:', nlp.parse(sentence))
# print('Constituency Parsing:', nlp.parse(sentence6))
# print('Constituency Parsing:', nlp.parse(sentence7))
# print('Constituency Parsing:', nlp.parse(sentence8))
# print('Dependency Parsing:', nlp.dependency_parse(sentence3))
# print('Dependency Parsing:', nlp.dependency_parse(sentence))
# parsed_tree = Tree.fromstring(stf_nlp.parse(sentence))

def parse_tree(sent):
    parsed_tree = Tree.fromstring(stf_nlp.parse(sent))
#     print(parsed_tree)
    
# np = [" ".join(i.leaves()) for i in parsed_tree.subtrees() if i.label() == 'NP']
# vp = [" ".join(i.leaves()) for i in parsed_tree.subtrees() if i.label() == 'VP']
# S = [" ".join(i.leaves()) for i in parsed_tree.subtrees() if i.label() == 'S']
# V = [" ".join(i.leaves()) for i in parsed_tree.subtrees() if i.label() == 'VBZ' or i.label() == 'VBG' or i.label() == 'VBN' or i.label() == 'VBP' or i.label() == 'VB']

# # if i = 'for' and (i+1).label() == 'VP': belong to function
# # if i = 'for' and (i+1).label() == 'NP': belong to category
# # if i = 'with' or other prep...
# func = [" ".join(i.leaves()) for i in parsed_tree.subtrees()]
# func1 = [" ".join(i.leaves()) for i in parsed_tree.subtrees() if i.leaves() == 'for']


#     print("---------")
# # print(np)
# print(vp)
# # print(S)
# # print(V)
# print("---------")
# print(func)
# print(len(func))
# print("---------")

#     for i in parsed_tree.subtrees():
#         print(i)



# print("-----------")

# for i in parsed_tree.subtrees():
#     # if i.leaves() == 'for':
#     if len(i.leaves()) == 1 and i.leaves()[0] == 'for': # i.leaves() is a list
#         print(i.leaves())

#     print("---------")
#     print(parsed_tree.pos())
# for i in parsed_tree.pos():
#     if i[1] == "VBG":
#         print(i[0])



    stf_nlp.close() # Do not forget to close! The backend server will consume a lot memery.
    return parsed_tree

# %%
tt = parse_tree(sentence)

print(tt.pos())
np = [" ".join(i.leaves()) for i in tt.subtrees() if i.label() == 'NP']
print(np)
parse_tree(sentence)
# Out:
# [('The', 'DT'), ('rplidar', 'NN'), ('ros', 'VBZ'), ('package', 'NN'), (',', ','), ('support', 'NN'), ('rplidar', 'NN'), ('A2', 'NN'), ('/', 'HYPH'), ('A1', 'NN'), ('and', 'CC'), ('A3', 'NN'), ('/', 'HYPH'), ('S1', 'NN')]
# ['The rplidar', 'package , support rplidar A2 / A1 and A3 / S1', 'package', 'support rplidar A2 / A1', 'A3 / S1']
# Tree('ROOT', [Tree('S', [Tree('NP', [Tree('DT', ['The']), Tree('NN', ['rplidar'])]), Tree('VP', [Tree('VBZ', ['ros']), Tree('NP', [Tree('NP', [Tree('NN', ['package'])]), Tree(',', [',']), Tree('NP', [Tree('NN', ['support']), Tree('NN', ['rplidar']), Tree('NML', [Tree('NN', ['A2']), Tree('HYPH', ['/']), Tree('NN', ['A1'])])]), Tree('CC', ['and']), Tree('NP', [Tree('NN', ['A3']), Tree('HYPH', ['/']), Tree('NN', ['S1'])])])])])])

# %% [markdown]
# # use nltk do pos-tagging

# %%
import nltk
from nltk.tag import pos_tag
def nltk_pos(sent):
    tagged_sent = pos_tag(sent.split())
    print(tagged_sent)
    pass
# nltk_pos(sentence)

# %%
nltk_pos("Launch files and scripts needed to bring up the ROS nodes of a REEM-C robot.")
nltk_pos("This package retrieves data from url-format files such as http://,   ftp://, package:// file://, etc., and loads the data into memory.   The package:// url for ros packages is translated into a local   file:// url.  The resourse retriever was initially designed to load   mesh files into memory, but it can be used for any type of   data. The resource retriever is based on the the libcurl library.")
nltk_pos("Time-Indexed RRT-Connect solver (Humanoids 2018)")
nltk_pos("SciPy-based Python solvers for Exotica")
# Out:
# [('Launch', 'JJ'), ('files', 'NNS'), ('and', 'CC'), ('scripts', 'NNS'), ('needed', 'VBN'), ('to', 'TO'), ('bring', 'VB'), ('up', 'RP'), ('the', 'DT'), ('ROS', 'NNP'), ('nodes', 'NNS'), ('of', 'IN'), ('a', 'DT'), ('REEM-C', 'JJ'), ('robot.', 'NN')]
# ...

# %%
nltk_pos("ILQG Solver (Todorov and Li, 2004)")
# Out:
# [('ILQG', 'NNP'), ('Solver', 'NNP'), ('(Todorov', 'NNP'), ('and', 'CC'), ('Li,', 'NNP'), ('2004)', 'CD')]

# %%
displacy.render(nlp(str("ILQG Solver (Todorov and Li, 2004)")), jupyter= True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">ILQG Solver (Todorov and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Li
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2004
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# )</div></span>

# %%
nltk_pos("TurtleBot3 AutoRace ROS package that TurtleBot3 Auto's core")
# Out:
# [('TurtleBot3', 'NNP'), ('AutoRace', 'NNP'), ('ROS', 'NNP'), ('package', 'NN'), ('that', 'WDT'), ('TurtleBot3', 'NNP'), ("Auto's", 'NNP'), ('core', 'NN')]

# %%
tb3_sent = "TurtleBot3 AutoRace ROS package that TurtleBot3 Auto's core"
parse_tree(tb3_sent)
# Out:
# (ROOT
#   (FRAG
#     (NP (NNP TurtleBot3) (NNP AutoRace) (NNP ROS))
#     (NP
#       (NP (NP (NN package)) (SBAR (WHNP (WDT that))))
#       (NP (NP (NNP TurtleBot3) (NNP Auto) (POS 's)) (NN core)))))
# ---------
# (ROOT
#   (FRAG
#     (NP (NNP TurtleBot3) (NNP AutoRace) (NNP ROS))
#     (NP
#       (NP (NP (NN package)) (SBAR (WHNP (WDT that))))
#       (NP (NP (NNP TurtleBot3) (NNP Auto) (POS 's)) (NN core)))))
# (FRAG
#   (NP (NNP TurtleBot3) (NNP AutoRace) (NNP ROS))
#   (NP
#     (NP (NP (NN package)) (SBAR (WHNP (WDT that))))
#     (NP (NP (NNP TurtleBot3) (NNP Auto) (POS 's)) (NN core))))
# (NP (NNP TurtleBot3) (NNP AutoRace) (NNP ROS))
# (NNP TurtleBot3)
# (NNP AutoRace)
# (NNP ROS)
# (NP
#   (NP (NP (NN package)) (SBAR (WHNP (WDT that))))
#   (NP (NP (NNP TurtleBot3) (NNP Auto) (POS 's)) (NN core)))
# (NP (NP (NN package)) (SBAR (WHNP (WDT that))))
# (NP (NN package))
# (NN package)
# (SBAR (WHNP (WDT that)))
# (WHNP (WDT that))
# (WDT that)
# ...
